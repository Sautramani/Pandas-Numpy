# %% [markdown]
# <a href="https://colab.research.google.com/github/Sautramani/Pandas-Numpy/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# series from list
country=['India','pakistan','usa','nepal']
pd.Series(country)  #series is a class and we are creating the objects for this
# Out:
# 0       India
# 1    pakistan
# 2         usa
# 3       nepal
# dtype: object

# %%
# custom index
marks=[67,57,89,100]
subjects=['english','maths','sst','hindi']
pd.Series(marks,index=subjects)
# Out:
# english     67
# maths       57
# sst         89
# hindi      100
# dtype: int64

# %%
# setting a name
#pd.Series(subjects,index=marks,name='sautramani')
marks=pd.Series(subjects,index=marks,name='sautramani')
marks
# Out:
# 67     english
# 57       maths
# 89         sst
# 100      hindi
# Name: sautramani, dtype: object

# %%
#MAKE SERIES USING CSV FILES
subs=pd.read_csv('/content/subs.csv').squeeze("columns")
print(type(subs))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1706/2059362584.py in <cell line: 0>()
#       1 #MAKE SERIES USING CSV FILES
# ----> 2 subs=pd.read_csv('/content/subs.csv').squeeze("columns")
#       3 print(type(subs))
#
# ...

# %%
df = pd.DataFrame({'A': [1, 2, 3]})
print(df)
print(df.squeeze("columns"))

# %%
#import csv file having 2 columns
vk=pd.read_csv('/content/kohli_ipl.csv',index_col='match_no').squeeze("columns")
vk

# %%
pd.read_csv('/content/bollywood.csv',index_col='lead').squeeze("columns")

# %%
# head()-> it gives  the preview of the dataset
subs=pd.read_csv('subs.csv').squeeze("columns")
bollywood =pd.read_csv('/content/bollywood.csv',index_col='lead').squeeze("columns")
#subs.head(10)
bollywood.head()

# %%
#tail()-> shows the last 5 values
subs.tail()

# %%
#sample()-> returns 1 random rows from dataset
subs.sample(10)  # it shows randomness on running it many times
subs.sample(5,random_state=3) #random_state se baar baar run karne ke baad result change nahi hoga (fixes the randomness)

# %%
# value_count() -> it counts frequency
bollywood.value_counts()
subs.value_counts()

# %%
#sort
subs.head(10)
subs.sort_values(ascending=False).head(10) #top 10  times for which max subscribers gain occured
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1706/4050975434.py in <cell line: 0>()
#       1 #sort
# ----> 2 subs.head(10)
#       3 subs.sort_values(ascending=False).head(10) #top 10  times for which max subscribers gain occured
#
# NameError: name 'subs' is not defined

# %%
subs.sort_index()

# %%
#count() ->  returns  the non-missing values
#( count values which are nt NaN)
subs.count()
bollywood.count()
len(bollywood)

bollywood.isnull().sum() # to count the number of missing(NaN) values

# %%
#mean
subs.mean()

# %%
#dtypes
subs.dtypes
bollywood.dtypes

# %%
#info()
subs.info()

# %%
#statistics involving things like:count,mean,std,min
kohli=pd.read_csv("kohli_ipl.csv")
kohli.describe()

# %%
#graphs
subs.plot()

# %%
bollywood =pd.read_csv('/content/bollywood.csv',index_col='movie').squeeze("columns")
bollywood.value_counts().head(20).plot(kind='pie')

# %%
#EDITING SERIES
subs[2]=1000
subs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1706/2842406565.py in <cell line: 0>()
#       1 #EDITING SERIES
# ----> 2 subs[2]=1000
#       3 subs
#
# NameError: name 'subs' is not defined

# %%
bollywood['priyanshu']="IITD"
bollywood

# %%
                   #DATAFRAMES
#create dataframe using list
student=[
    [100,200,300],
    [150,250,350],
    [777,666,555]
]
pd.DataFrame(student,columns=["iq","marks","package"])

# %%
#using dictionary
student_dict={
    'name':['vibhu','a','b','c','d'],
    'iq':[100,200,120,888,789],
    'marks':[80,100,90,12,457],
    'package':[10,40,15,75,99]
}
students=pd.DataFrame(student_dict)
students
# Out:
#     name   iq  marks  package
# 0  vibhu  100     80       10
# 1      a  200    100       40
# 2      b  120     90       15
# 3      c  888     12       75
# 4      d  789    457       99

# %%
#using read_csv
movies=pd.read_csv('/content/movies.csv')
movies

# %%
ipl=pd.read_csv('/content/ipl-matches.csv')
ipl

# %%
#shape: Returns a tuple (rows, columns) representing DataFrame dimensions.
movies.shape
# Out:
# (1629, 18)

# %%
# Output: RangeIndex(start=0, stop=1629, step=1)
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
#values: Converts the DataFrame content into a raw 2D NumPy array.
ipl.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
#sample(n): Pulls $n$ random rows to get an unbiased look at data.
movies.sample(5)
# Out:
#                title_x    imdb_id  \
# 1590       Deewaanapan  tt0301179
# 982       Jodhaa Akbar  tt0449994
# 1334   Dil Maange More  tt0328729
# 221      Simran (film)  tt6405126
# 82    My Birthday Song  tt4335954
#
#                                             poster_path  \
# 1590  https://upload.wikimedia.org/wikipedia/en/thum...
# 982   https://upload.wikimedia.org/wikipedia/en/thum...
# 1334  https://upload.wikimedia.org/wikipedia/en/thum...
# 221   https://upload.wikimedia.org/wikipedia/en/thum...
# 82    https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link             title_y  \
# 1590       https://en.wikipedia.org/wiki/Deewaanapan         Deewaanapan
# 982       https://en.wikipedia.org/wiki/Jodhaa_Akbar        Jodhaa Akbar
# 1334   https://en.wikipedia.org/wiki/Dil_Maange_More  Dil Maange More!!!
# 221      https://en.wikipedia.org/wiki/Simran_(film)              Simran
# ...

# %%
#describe(): Generates summary statistics (mean, std, min, max, percentiles) for numerical columns.
movies.describe
ipl.describe
# Out:
# <bound method NDFrame.describe of           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# ...

# %%
#ipl.isnull().sum()
# Shows missing values per column (e.g., City has 51 missing values)
ipl.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
#duplicated(): Identifies duplicate rows. Chain with .sum() to count total complete duplicates.
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
  #MATHEMATICAL METHODS
students.sum(axis=1) #row wise
# Out:
# 0     190
# 1     340
# 2     225
# 3     975
# 4    1345
# dtype: int64

# %%
#Apply min, max, mean on single columns
students['marks'].mean()
# Out:
# np.float64(147.8)

# %%
students.min() # columnwise min
# Out:
# iq         100
# marks       12
# package     10
# dtype: int64

# %%
#fetching multiple columns
movies[['title_x','year_of_release','actors']]
# Out:
#                                    title_x  year_of_release  \
# 0                 Uri: The Surgical Strike             2019
# 1                            Battalion 609             2019
# 2     The Accidental Prime Minister (film)             2019
# 3                          Why Cheat India             2019
# 4                          Evening Shadows             2018
# ...                                    ...              ...
# 1624                 Tera Mera Saath Rahen             2001
# 1625                  Yeh Zindagi Ka Safar             2001
# 1626                       Sabse Bada Sukh             2018
# 1627                                 Daaka             2019
# 1628                              Humsafar             2011
#
#                                                  actors
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# ...

# %%
 #fetching rows and multiple rows using
 #iloc-> searches using index positions
 #loc-> searches using index labels
 movies.iloc[0]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
movies.iloc[[0,4,7]]
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 4           Evening Shadows  tt6028796
# 7                Bombairiya  tt4971258
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 7  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 7           https://en.wikipedia.org/wiki/Bombairiya
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 4           Evening Shadows           Evening Shadows         0
# 7                Bombairiya                Bombairiya         0
#
#    year_of_release runtime              genres  imdb_rating  imdb_votes  \
# ...

# %%
#loc
student_dict={
    'name':['vibhu','a','b','c','d'],
    'iq':[100,200,120,888,789],
    'marks':[80,100,90,12,457],
    'package':[10,40,15,75,99]
}
students=pd.DataFrame(student_dict)
students
students.loc[1] # return  row whose index label is 1.
# Out:
# name         a
# iq         200
# marks      100
# package     40
# Name: 1, dtype: object

# %%
# loc for rows+columns
movies.iloc[0:3,0:3]
movies.loc[0:2,'title_x':'poster_path']
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
